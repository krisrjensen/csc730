# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset, SE330_193749481_2024_01_21.txt
dataset = pd.read_csv('SE330_193749481_2024_01_21.txt', delimiter = '\t')

#print first 10 rows
print(dataset.head(10))
# Out:
#         Time  Record Count          TRIPSTATUS             \
# 0  00:00:02                      39              No Trips
# 1  00:00:04                      39              No Trips
# 2  00:00:06                      39              No Trips
# 3  00:00:08                      39              No Trips
# 4  00:00:10                      39              No Trips
# 5  00:00:13                      39              No Trips
# 6  00:00:15                      39              No Trips
# 7  00:00:17                      39              No Trips
# 8  00:00:19                      39              No Trips
# 9  00:00:21                      39              No Trips
#
#   Device Status         Diagnostic            K1 Operation S1      \
# 0              No Trips             No Errors                Trip
# 1              No Trips             No Errors                Trip
# 2              No Trips             No Errors                Trip
# 3              No Trips             No Errors                Trip
# 4              No Trips             No Errors                Trip
# 5              No Trips             No Errors                Trip
# 6              No Trips             No Errors                Trip
# 7              No Trips             No Errors                Trip
# 8              No Trips             No Errors                Trip
# 9              No Trips             No Errors                Trip
#
#    K1 Relay Assignment   K1 Fail-Safe S2     K1 Trip Relay          \
# 0  GF + RF + Health Trip           Fail-Safe             Energized
# 1  GF + RF + Health Trip           Fail-Safe             Energized
# 2  GF + RF + Health Trip           Fail-Safe             Energized
# 3  GF + RF + Health Trip           Fail-Safe             Energized
# 4  GF + RF + Health Trip           Fail-Safe             Energized
# 5  GF + RF + Health Trip           Fail-Safe             Energized
# 6  GF + RF + Health Trip           Fail-Safe             Energized
# 7  GF + RF + Health Trip           Fail-Safe             Energized
# 8  GF + RF + Health Trip           Fail-Safe             Energized
# 9  GF + RF + Health Trip           Fail-Safe             Energized
#
#   K2 Relay Assignment    ... SDCARD Status         Flash Healthy          \
# 0          Ground Fault  ...          Card Logging               HEALTHY
# 1          Ground Fault  ...          Card Logging               HEALTHY
# 2          Ground Fault  ...          Card Logging               HEALTHY
# 3          Ground Fault  ...          Card Logging               HEALTHY
# 4          Ground Fault  ...          Card Logging               HEALTHY
# 5          Ground Fault  ...          Card Logging               HEALTHY
# 6          Ground Fault  ...          Card Logging               HEALTHY
# 7          Ground Fault  ...          Card Logging               HEALTHY
# 8          Ground Fault  ...          Card Logging               HEALTHY
# 9          Ground Fault  ...          Card Logging               HEALTHY
#
#   Watchdog              FACTORY DIAG IV_Valid FACTORY DIAG Boot      \
# 0             No Errors             Not Valid                     4
# 1             No Errors             Not Valid                     4
# 2             No Errors             Not Valid                     4
# 3             No Errors             Not Valid                     4
# 4             No Errors             Not Valid                     4
# 5             No Errors             Not Valid                     4
# 6             No Errors             Not Valid                     4
# 7             No Errors             Not Valid                     4
# 8             No Errors             Not Valid                     4
# 9             No Errors             Not Valid                     4
#
#   FACTORY DIAG Rc       FACTORY DIAG Rd        FACTORY DIAG Cd        \
# 0                     0                   175                  24735
# 1                     0                   175                  24725
# 2                     0                   175                  24712
# 3                     0                   175                  24666
# 4                     0                   175                  24728
# 5                     0                   174                  24731
# 6                     0                   175                  24752
# 7                     0                   175                  24736
# 8                     0                   174                  24732
# 9                     0                   174                  24708
#
#    FACTORY DIAG Calib     Unnamed: 54
# 0                     74          NaN
# 1                     74          NaN
# 2                     74          NaN
# 3                     74          NaN
# 4                     74          NaN
# 5                     74          NaN
# 6                     74          NaN
# 7                     74          NaN
# 8                     74          NaN
# 9                     74          NaN
#
# [10 rows x 55 columns]

# %%
#print all field names
print(dataset.columns)

#trim all spaces and replace % with percent
dataset.columns = dataset.columns.str.strip().str.replace(' ', '_').str.replace('%', 'percent')
print(dataset.columns)
# Out:
# Index(['Time', 'Record Count         ', 'TRIPSTATUS           ',
#        'Device Status        ', 'Diagnostic           ', 'K1 Operation S1    ',
#        'K1 Relay Assignment  ', 'K1 Fail-Safe S2    ', 'K1 Trip Relay        ',
#        'K2 Relay Assignment  ', 'K2 Mode              ',
#        'K2 Trip Relay        ', 'K3 Relay Assignment  ',
#        'K3 Mode              ', 'K3 Trip Relay        ',
#        'GF-LATCH (S3)        ', 'RF-LATCH S4        ', 'NGR Current (%FS)    ',
#        'NGR Voltage (%Setting) ', 'Calculated NGR Current (A)',
#        'Calculated NGR Voltage (V)', 'Nominal NGR (ohms)',
#        'R Change from Calibration (ohms)', 'NGR Resistance (ohms)',
#        'NGR Resistance (% Nominal)', 'NGR Polarity         ',
#        'NGR Short Mode       ', 'NGR Open Mode        ',
#        'NGR Sensitive Short Trip Level (% Nominal)',
#        'NGR Sensitive Open Trip Level  (% Nominal)', 'RF Trip Time (s)     ',
#        'Standard RF Trip Level (ohms)', 'Pulse Enable         ',
#        'Pulse Time (s)       ', 'Vn Trip Level (V)    ',
#        'Sensing Resistor S5 (K) ', 'GF Time (s)          ',
#        'GF Trip Level (%)    ', 'GF Setting Memory (%)',
#        'Effective CT Primary (A)', 'Frequency S6 (Hz)  ',
#        'GF Trip Time Mode    ', 'Hardware Version     ',
#        'Firmware Version     ', 'Upgrade Switch (S8)  ',
#        'SDCARD Status        ', 'Flash Healthy        ',
#        'Watchdog             ', 'FACTORY DIAG IV_Valid',
#        'FACTORY DIAG Boot    ', 'FACTORY DIAG Rc      ',
#        'FACTORY DIAG Rd      ', 'FACTORY DIAG Cd      ',
#        'FACTORY DIAG Calib   ', 'Unnamed: 54'],
#       dtype='object')
# Index(['Time', 'Record_Count', 'TRIPSTATUS', 'Device_Status', 'Diagnostic',
#        'K1_Operation_S1', 'K1_Relay_Assignment', 'K1_Fail-Safe_S2',
#        'K1_Trip_Relay', 'K2_Relay_Assignment', 'K2_Mode', 'K2_Trip_Relay',
#        'K3_Relay_Assignment', 'K3_Mode', 'K3_Trip_Relay', 'GF-LATCH_(S3)',
#        'RF-LATCH_S4', 'NGR_Current_(percentFS)',
#        'NGR_Voltage_(percentSetting)', 'Calculated_NGR_Current_(A)',
#        'Calculated_NGR_Voltage_(V)', 'Nominal_NGR_(ohms)',
#        'R_Change_from_Calibration_(ohms)', 'NGR_Resistance_(ohms)',
#        'NGR_Resistance_(percent_Nominal)', 'NGR_Polarity', 'NGR_Short_Mode',
#        'NGR_Open_Mode', 'NGR_Sensitive_Short_Trip_Level_(percent_Nominal)',
#        'NGR_Sensitive_Open_Trip_Level__(percent_Nominal)', 'RF_Trip_Time_(s)',
#        'Standard_RF_Trip_Level_(ohms)', 'Pulse_Enable', 'Pulse_Time_(s)',
#        'Vn_Trip_Level_(V)', 'Sensing_Resistor_S5_(K)', 'GF_Time_(s)',
#        'GF_Trip_Level_(percent)', 'GF_Setting_Memory_(percent)',
#        'Effective_CT_Primary_(A)', 'Frequency_S6_(Hz)', 'GF_Trip_Time_Mode',
#        'Hardware_Version', 'Firmware_Version', 'Upgrade_Switch_(S8)',
#        'SDCARD_Status', 'Flash_Healthy', 'Watchdog', 'FACTORY_DIAG_IV_Valid',
#        'FACTORY_DIAG_Boot', 'FACTORY_DIAG_Rc', 'FACTORY_DIAG_Rd',
#        'FACTORY_DIAG_Cd', 'FACTORY_DIAG_Calib', 'Unnamed:_54'],
#       dtype='object')

# %%
#plot the following fields:
#NGR Current (\%FS)
#NGR Voltage (\%Setting) 	
#Calculated NGR Current (A)	
#Calculated NGR Voltage (V)	
#Nominal NGR (ohms)	
#R Change from Calibration (ohms)	
#NGR Resistance (ohms)	
#NGR Resistance (\% Nominal)	
#NGR Polarity         	
#NGR Short Mode       	
#NGR Open Mode        	
#NGR Sensitive Short Trip Level (\% Nominal)	
#NGR Sensitive Open Trip Level  (\% Nominal)	
#RF Trip Time (s)     	
#Standard RF Trip Level (ohms)	
#Pulse Enable         	
#Pulse Time (s)       	
#Vn Trip Level (V)    	
#Sensing Resistor S5 (K) 	
#GF Time (s)          	
#GF Trip Level (\%)

field_list = ['NGR_Current_(percentFS)', 'NGR_Voltage_(percentSetting)', 'Calculated_NGR_Current_(A)', 'Calculated_NGR_Voltage_(V)', 
              'Nominal_NGR_(ohms)', 'R_Change_from_Calibration_(ohms)', 'NGR_Resistance_(ohms)', 'NGR_Resistance_(percent_Nominal)',
              'NGR_Polarity', 'NGR_Short_Mode', 'NGR_Open_Mode', 'NGR_Sensitive_Short_Trip_Level_(percent_Nominal)', 'NGR_Sensitive_Open_Trip_Level_(percent_Nominal)',
                'RF_Trip_Time_(s)', 'Standard_RF_Trip_Level_(ohms)', 'Pulse_Enable', 'Pulse_Time_(s)', 'Vn_Trip_Level_(V)', 'Sensing_Resistor_S5_(K)', 'GF_Time_(s)', 'GF_Trip_Level_(percent)']

for field in field_list:
    plt.plot(dataset[field])
    plt.title(field)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File h:\dev\git\csc730\.venv\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NGR Current (%%FS)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 30
#      24 field_list = ['NGR Current (%%FS)', 'NGR Voltage (%%Setting)', 'Calculated NGR Current (A)', 'Calculated NGR Voltage (V)',
#      25               'Nominal NGR (ohms)', 'R Change from Calibration (ohms)', 'NGR Resistance (ohms)', 'NGR Resistance (\% Nominal)',
#      26               'NGR Polarity', 'NGR Short Mode', 'NGR Open Mode', 'NGR Sensitive Short Trip Level (\% Nominal)', 'NGR Sensitive Open Trip Level  (\% Nominal)',
#      27                 'RF Trip Time (s)', 'Standard RF Trip Level (ohms)', 'Pulse Enable', 'Pulse Time (s)', 'Vn Trip Level (V)', 'Sensing Resistor S5 (K)', 'GF Time (s)', 'GF Trip Level (\%)']
#      29 for field in field_list:
# ---> 30     plt.plot(dataset[field])
#      31     plt.title(field)
#      32     plt.show()
#
# File h:\dev\git\csc730\.venv\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File h:\dev\git\csc730\.venv\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'NGR Current (%%FS)'
